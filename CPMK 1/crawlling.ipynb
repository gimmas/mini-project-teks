# %% [markdown]
# <a href="https://colab.research.google.com/github/gimmas/mini-project-teks/blob/main/crawlling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# To crawl YouTube comments using the YouTube Data API, you'll need to install the Google API client library.

# %%
# !pip install google-api-python-client

# %%
# Import necessary libraries
from googleapiclient.discovery import build
import pandas as pd

# %%
# Replace with your API key and video ID
api_key = "AIzaSyBZ37eeoC9-bZ5iuXsp_aqaJhQ7tgSUeYE"
video_id = "P1NbOV7avUs"
max_results = 10000 # Desired number of comments

# Build the YouTube Data API client
youtube = build('youtube', 'v3', developerKey=api_key)

comments = []
next_page_token = None

while len(comments) < max_results:
    try:
        # Get comments for the video
        results = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=min(100, max_results - len(comments)),
            pageToken=next_page_token
        ).execute()

        for item in results["items"]:
            comment = item["snippet"]["topLevelComment"]["snippet"]
            comments.append({
                'author': comment["authorDisplayName"],
                'published_at': comment["publishedAt"],
                'text': comment["textDisplay"]
            })

        next_page_token = results.get('nextPageToken')

        if not next_page_token:
            break # No more pages

    except Exception as e:
        print(f"An error occurred: {e}")
        break # Exit loop if an error occurs

print(f"Successfully crawled {len(comments)} comments.")

# You can now convert the comments list to a pandas DataFrame or save it to a file.
comments_df = pd.DataFrame(comments)
display(comments_df.head())
# Out:
# Successfully crawled 2167 comments.
#                    author          published_at  \
# 0      @camatkaliguwo5666  2025-10-06T16:17:22Z
# 1             @reyy_afz34  2025-10-06T13:28:37Z
# 2                @Karis-b  2025-10-06T11:32:17Z
# 3             @habibi3722  2025-10-06T11:03:10Z
# 4  @shadow_milk_cookie182  2025-10-06T10:34:07Z
#
#                                                 text
# 0                        Kaget kalidawir tulungagung
# 1  10000000000000% nyesel pilih Prabowo enak anie...
# 2                        Jirr semangka setipis tisu😂
# 3  di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4  Bang kalo makanan MBG itu ada racunnya atau gm...

# %%
display(comments_df)
# Out:
#                          author          published_at  \
# 0            @camatkaliguwo5666  2025-10-06T16:17:22Z
# 1                   @reyy_afz34  2025-10-06T13:28:37Z
# 2                      @Karis-b  2025-10-06T11:32:17Z
# 3                   @habibi3722  2025-10-06T11:03:10Z
# 4        @shadow_milk_cookie182  2025-10-06T10:34:07Z
# ...                         ...                   ...
# 2162               @Riswanz-l2g  2025-09-26T09:49:59Z
# 2163                    @Fatqul  2025-09-26T09:49:52Z
# 2164                 @AvinZidan  2025-09-26T09:49:49Z
# 2165  @nezzralmuhammadyusuf4757  2025-09-26T09:49:42Z
# 2166            @LaskarJaya-v4v  2025-09-26T09:49:38Z
#
#                                                    text
# 0                           Kaget kalidawir tulungagung
# 1     10000000000000% nyesel pilih Prabowo enak anie...
# 2                           Jirr semangka setipis tisu😂
# 3     di. daerah Kalimantan Selatan Tabalong.  ayam ...
# ...

# %%
import os

# Define the directory path and filename
directory_path = '/content/drive/MyDrive/Tugas/TEKS/CSV'
filename = 'youtube_comments.csv'
file_path = os.path.join(directory_path, filename)

# Create the directory if it doesn't exist
os.makedirs(directory_path, exist_ok=True)

# Save the DataFrame to a CSV file
comments_df.to_csv(file_path, index=False)

print(f"Comments saved to {file_path}")
# Out:
# Comments saved to /content/drive/MyDrive/Tugas/TEKS/CSV/youtube_comments.csv
