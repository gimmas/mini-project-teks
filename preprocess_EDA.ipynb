# %% [markdown]
# <a href="https://colab.research.google.com/github/gimmas/mini-project-teks/blob/main/preprocess_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import re
import nltk
from nltk.corpus import stopwords

# Download necessary NLTK data
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt')
try:
    nltk.data.find('corpora/stopwords')
except LookupError:
    nltk.download('stopwords')

# %%
# Install Sastrawi
# !pip install Sastrawi
# Out:
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.12/dist-packages (1.0.1)

# %%
# Import necessary libraries
from googleapiclient.discovery import build
import pandas as pd

# %%
import pandas as pd

# Define the file path
file_path = '/content/drive/MyDrive/Tugas/TEKS/CSV/youtube_comments.csv'

# Read the CSV file into a pandas DataFrame
try:
    saved_comments_df = pd.read_csv(file_path)
    print(f"Successfully read data from {file_path}")
    display(saved_comments_df)

except FileNotFoundError:
    print(f"Error: The file {file_path} was not found.")
except Exception as e:
    print(f"An error occurred while reading the CSV file: {e}")
# Out:
# Successfully read data from /content/drive/MyDrive/Tugas/TEKS/CSV/youtube_comments.csv
#                          author          published_at  \
# 0            @camatkaliguwo5666  2025-10-06T16:17:22Z
# 1                   @reyy_afz34  2025-10-06T13:28:37Z
# 2                      @Karis-b  2025-10-06T11:32:17Z
# 3                   @habibi3722  2025-10-06T11:03:10Z
# 4        @shadow_milk_cookie182  2025-10-06T10:34:07Z
# ...                         ...                   ...
# 2162               @Riswanz-l2g  2025-09-26T09:49:59Z
# 2163                    @Fatqul  2025-09-26T09:49:52Z
# 2164                 @AvinZidan  2025-09-26T09:49:49Z
# 2165  @nezzralmuhammadyusuf4757  2025-09-26T09:49:42Z
# 2166            @LaskarJaya-v4v  2025-09-26T09:49:38Z
#
#                                                    text
# 0                           Kaget kalidawir tulungagung
# 1     10000000000000% nyesel pilih Prabowo enak anie...
# 2                           Jirr semangka setipis tisu😂
# 3     di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4     Bang kalo makanan MBG itu ada racunnya atau gm...
# ...                                                 ...
# 2162                                       Pertama bang
# 2163                                            Pertama
# 2164                                            Pertama
# 2165                                              First
# 2166                                               Halo
#
# [2167 rows x 3 columns]

# %% [markdown]
# #lihat data raw

# %%
import re
# Import Sastrawi stopword remover
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# Create stop word remover
factory = StopWordRemoverFactory()
stopword_remover = factory.create_stop_word_remover()

# Function to remove stop words from a string using Sastrawi
def remove_stopwords_sastrawi(text):
    # Ensure text is a string
    if not isinstance(text, str):
        return text
    return stopword_remover.remove(text)


# Apply the stop word removal function to the original 'text' column
saved_comments_df['unchanged_wordcloud'] = saved_comments_df['text'].apply(remove_stopwords_sastrawi)

print("Stop words removed from the original text using Sastrawi and stored in 'unchanged_wordcloud' column.")
display(saved_comments_df.head())
# Out:
# Stop words removed from the original text using Sastrawi and stored in 'unchanged_wordcloud' column.
#                    author          published_at  \
# 0      @camatkaliguwo5666  2025-10-06T16:17:22Z
# 1             @reyy_afz34  2025-10-06T13:28:37Z
# 2                @Karis-b  2025-10-06T11:32:17Z
# 3             @habibi3722  2025-10-06T11:03:10Z
# 4  @shadow_milk_cookie182  2025-10-06T10:34:07Z
#
#                                                 text  \
# 0                        Kaget kalidawir tulungagung
# 1  10000000000000% nyesel pilih Prabowo enak anie...
# 2                        Jirr semangka setipis tisu😂
# 3  di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4  Bang kalo makanan MBG itu ada racunnya atau gm...
#
#                                  unchanged_wordcloud
# 0                        Kaget kalidawir tulungagung
# 1  10000000000000% nyesel pilih Prabowo enak anie...
# 2                        Jirr semangka setipis tisu😂
# 3  di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4  Bang kalo makanan MBG ada racunnya gmn. Menuru...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Combine all the strings in the 'unchanged_wordcloud' column into a single string
wordcloud_text = ' '.join(saved_comments_df['unchanged_wordcloud'].astype(str))

# Create and generate a wordcloud image
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate(wordcloud_text)

# Display the generated word cloud image
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Original YouTube Comments (Stop words removed)')
plt.show()

# %%
from collections import Counter

# Combine all the strings in the 'unchanged_wordcloud' column into a single string
wordcloud_text_unchanged = ' '.join(saved_comments_df['unchanged_wordcloud'].astype(str))

# Tokenize the combined string (simple split by space)
tokens_unchanged = wordcloud_text_unchanged.split()

# Count the frequency of each token
word_counts_unchanged = Counter(tokens_unchanged)

# Get the most common words (e.g., top 20)
most_common_words_unchanged = word_counts_unchanged.most_common(20)

print("Most common words from the 'unchanged_wordcloud' column:")
for word, count in most_common_words_unchanged:
    print(f"{word}: {count}")
# Out:
# Most common words from the 'unchanged_wordcloud' column:
# nya: 373
# yg: 312
# MBG: 270
# makan: 251
# mbg: 247
# gw: 239
# sekolah: 202
# aja: 179
# gak: 176
# gratis: 174
# makanan: 148
# keracunan: 133
# gua: 130
# aku: 118
# korupsi: 118
# beracun: 117
# program: 115
# jadi: 115
# sama: 112
# bergizi: 107

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure most_common_words_unchanged is available from the previous cell
if 'most_common_words_unchanged' in locals():
    # Prepare data for visualization
    words_unchanged, counts_unchanged = zip(*most_common_words_unchanged)

    # Create a bar plot
    plt.figure(figsize=(12, 8))
    sns.barplot(x=list(counts_unchanged), y=list(words_unchanged), palette='viridis')
    plt.title('Top 20 Most Frequent Words (Original Text with Stop words removed)')
    plt.xlabel('Frequency')
    plt.ylabel('Words')
    plt.show()
else:
    print("Error: 'most_common_words_unchanged' not found. Please run the previous cell to identify the most common words first.")
# Out:
# /tmp/ipython-input-37825514.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(counts_unchanged), y=list(words_unchanged), palette='viridis')

# %% [markdown]
# # **preprocess**

# %% [markdown]
# ##cleaning
# cleaning duplicate, url, html, mention/hashtag, emoji, numbers

# %%
# Remove duplicate rows
initial_rows = len(saved_comments_df)
saved_comments_df.drop_duplicates(inplace=True)
rows_after_dropping = len(saved_comments_df)

print(f"Initial number of rows: {initial_rows}")
print(f"Number of rows after dropping duplicates: {rows_after_dropping}")

if initial_rows > rows_after_dropping:
    print(f"Removed {initial_rows - rows_after_dropping} duplicate rows.")
else:
    print("No duplicate rows found.")

display(saved_comments_df.head())
# Out:
# Initial number of rows: 2167
# Number of rows after dropping duplicates: 2167
# No duplicate rows found.
#                    author          published_at  \
# 0      @camatkaliguwo5666  2025-10-06T16:17:22Z
# 1             @reyy_afz34  2025-10-06T13:28:37Z
# 2                @Karis-b  2025-10-06T11:32:17Z
# 3             @habibi3722  2025-10-06T11:03:10Z
# 4  @shadow_milk_cookie182  2025-10-06T10:34:07Z
#
#                                                 text  \
# 0                        Kaget kalidawir tulungagung
# 1  10000000000000% nyesel pilih Prabowo enak anie...
# 2                        Jirr semangka setipis tisu😂
# 3  di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4  Bang kalo makanan MBG itu ada racunnya atau gm...
#
#                                  unchanged_wordcloud
# 0                        Kaget kalidawir tulungagung
# 1  10000000000000% nyesel pilih Prabowo enak anie...
# 2                        Jirr semangka setipis tisu😂
# 3  di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4  Bang kalo makanan MBG ada racunnya gmn. Menuru...

# %%
import re

# Function to remove URLs
def remove_urls(text):
    # Ensure text is a string
    if not isinstance(text, str):
        return text
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)

# Function to remove HTML tags and web elements (refined)
def remove_html_tags(text):
    # Ensure text is a string
    if not isinstance(text, str):
        return text
    # This pattern is more comprehensive for HTML tags, including attributes and content within tags
    html_pattern = re.compile(r'<[^>]+>')
    # Replace with a space instead of an empty string
    cleaned_text = html_pattern.sub(r' ', text)

    # Also remove common HTML entities
    html_entity_pattern = re.compile(r'&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
    cleaned_text = html_entity_pattern.sub(r' ', cleaned_text)

    # Remove any extra whitespaces that might result from removal
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()

    return cleaned_text


# Function to remove mentions and hashtags
def remove_mentions_hashtags(text):
    # Ensure text is a string
    if not isinstance(text, str):
        return text
    pattern = re.compile(r'@\w+|\#\w+')
    return pattern.sub(r'', text)

# Function to remove emojis (more comprehensive)
def remove_emojis(text):
    # Ensure text is a string
    if not isinstance(text, str):
        return text
    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F"  # Emoticons
        "\U0001F300-\U0001F5FF"  # Symbols and Pictographs
        "\U0001F680-\U0001F6FF"  # Transport and Map Symbols
        "\U0001F1E0-\U0001F1FF"  # Flags (iOS)
        "\U00002500-\U00002B50"  # Box Drawing and Miscellaneous Symbols
        "\U00002700-\U000027BF"  # Dingbats
        "\U0000FE00-\U0000FE0F"  # Variation Selectors
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA00-\U0001FA6F"  # Chess Symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        "\U0000200D" # Zero Width Joiner
        "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# Function to remove numbers
def remove_numbers(text):
    # Ensure text is a string
    if not isinstance(text, str):
        return text
    return re.sub(r'\d+', '', text)


# Apply the functions to the 'text' column in order
saved_comments_df['clean_text'] = saved_comments_df['text'].apply(remove_urls)
saved_comments_df['clean_text'] = saved_comments_df['clean_text'].apply(remove_html_tags)
saved_comments_df['clean_text'] = saved_comments_df['clean_text'].apply(remove_mentions_hashtags)
saved_comments_df['clean_text'] = saved_comments_df['clean_text'].apply(remove_emojis)
saved_comments_df['clean_text'] = saved_comments_df['clean_text'].apply(remove_numbers)


print("Preprocessing steps applied: Removing URLs, HTML tags, mentions, hashtags, emojis, and numbers.")
display(saved_comments_df.head(100))
# Out:
# Preprocessing steps applied: Removing URLs, HTML tags, mentions, hashtags, emojis, and numbers.
#                     author          published_at  \
# 0       @camatkaliguwo5666  2025-10-06T16:17:22Z
# 1              @reyy_afz34  2025-10-06T13:28:37Z
# 2                 @Karis-b  2025-10-06T11:32:17Z
# 3              @habibi3722  2025-10-06T11:03:10Z
# 4   @shadow_milk_cookie182  2025-10-06T10:34:07Z
# ..                     ...                   ...
# 95             @fanhayo_go  2025-10-03T11:33:06Z
# 96             @putrooorwr  2025-10-03T11:31:08Z
# 97            @d3n1permana  2025-10-03T11:02:20Z
# 98          @userememaja11  2025-10-03T10:53:12Z
# 99            @aryanor8036  2025-10-03T10:52:14Z
#
#                                                  text  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                   unchanged_wordcloud  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG ada racunnya gmn. Menuru...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku masak nya malam bukan siang ...
#
#                                            clean_text
# 0                         Kaget kalidawir tulungagung
# 1   % nyesel pilih Prabowo enak aniess pendidikan ...
# 2                          Jirr semangka setipis tisu
# 3   di. daerah Kalimantan Selatan Tabalong. ayam g...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                     B for beracun
# 97    Daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
# [100 rows x 5 columns]

# %%
# 1. Case Folding (already done in cell 6_wq8Wqc1q4A, but including for completeness)
saved_comments_df['case_fold_text'] = saved_comments_df['clean_text'].str.lower()
print("Preprocessing steps applied: Case Folding.")
display(saved_comments_df.head(100))
# Out:
# Preprocessing steps applied: Case Folding.
#                     author          published_at  \
# 0       @camatkaliguwo5666  2025-10-06T16:17:22Z
# 1              @reyy_afz34  2025-10-06T13:28:37Z
# 2                 @Karis-b  2025-10-06T11:32:17Z
# 3              @habibi3722  2025-10-06T11:03:10Z
# 4   @shadow_milk_cookie182  2025-10-06T10:34:07Z
# ..                     ...                   ...
# 95             @fanhayo_go  2025-10-03T11:33:06Z
# 96             @putrooorwr  2025-10-03T11:31:08Z
# 97            @d3n1permana  2025-10-03T11:02:20Z
# 98          @userememaja11  2025-10-03T10:53:12Z
# 99            @aryanor8036  2025-10-03T10:52:14Z
#
#                                                  text  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                   unchanged_wordcloud  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG ada racunnya gmn. Menuru...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku masak nya malam bukan siang ...
#
#                                            clean_text  \
# 0                         Kaget kalidawir tulungagung
# 1   % nyesel pilih Prabowo enak aniess pendidikan ...
# 2                          Jirr semangka setipis tisu
# 3   di. daerah Kalimantan Selatan Tabalong. ayam g...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                     B for beracun
# 97    Daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                        case_fold_text
# 0                         kaget kalidawir tulungagung
# 1   % nyesel pilih prabowo enak aniess pendidikan ...
# 2                          jirr semangka setipis tisu
# 3   di. daerah kalimantan selatan tabalong. ayam g...
# 4   bang kalo makanan mbg itu ada racunnya atau gm...
# ..                                                ...
# 95    mbg kalau gua pikir makanan beracun gratis jirr
# 96                                     b for beracun
# 97    daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
# [100 rows x 6 columns]

# %%
# 2. Removing Punctuation
def remove_punctuation(text):
    # Ensure text is a string before applying lower()
    if not isinstance(text, str):
        return text
    return re.sub(r'[^\w\s]', '', text.lower()) # Apply lower() here for consistency

saved_comments_df['punctuation_text'] = saved_comments_df['case_fold_text'].apply(remove_punctuation)
print("Preprocessing steps applied: Case Folding, Removing Punctuation.")
display(saved_comments_df.head(100))
# Out:
# Preprocessing steps applied: Case Folding, Removing Punctuation.
#                     author          published_at  \
# 0       @camatkaliguwo5666  2025-10-06T16:17:22Z
# 1              @reyy_afz34  2025-10-06T13:28:37Z
# 2                 @Karis-b  2025-10-06T11:32:17Z
# 3              @habibi3722  2025-10-06T11:03:10Z
# 4   @shadow_milk_cookie182  2025-10-06T10:34:07Z
# ..                     ...                   ...
# 95             @fanhayo_go  2025-10-03T11:33:06Z
# 96             @putrooorwr  2025-10-03T11:31:08Z
# 97            @d3n1permana  2025-10-03T11:02:20Z
# 98          @userememaja11  2025-10-03T10:53:12Z
# 99            @aryanor8036  2025-10-03T10:52:14Z
#
#                                                  text  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                   unchanged_wordcloud  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG ada racunnya gmn. Menuru...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku masak nya malam bukan siang ...
#
#                                            clean_text  \
# 0                         Kaget kalidawir tulungagung
# 1   % nyesel pilih Prabowo enak aniess pendidikan ...
# 2                          Jirr semangka setipis tisu
# 3   di. daerah Kalimantan Selatan Tabalong. ayam g...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                     B for beracun
# 97    Daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                        case_fold_text  \
# 0                         kaget kalidawir tulungagung
# 1   % nyesel pilih prabowo enak aniess pendidikan ...
# 2                          jirr semangka setipis tisu
# 3   di. daerah kalimantan selatan tabalong. ayam g...
# 4   bang kalo makanan mbg itu ada racunnya atau gm...
# ..                                                ...
# 95    mbg kalau gua pikir makanan beracun gratis jirr
# 96                                     b for beracun
# 97    daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                      punctuation_text
# 0                         kaget kalidawir tulungagung
# 1    nyesel pilih prabowo enak aniess pendidikan g...
# 2                          jirr semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   bang kalo makanan mbg itu ada racunnya atau gm...
# ..                                                ...
# 95    mbg kalau gua pikir makanan beracun gratis jirr
# 96                                     b for beracun
# 97    daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes nikmati aja kalo semua orang baik...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
# [100 rows x 7 columns]

# %%
print("Preprocessing steps applied: Case Folding, Removing Punctuation, and Standardizing words.")
display(saved_comments_df.head(100))
# Out:
# Preprocessing steps applied: Case Folding, Removing Punctuation, and Standardizing words.
#                     author          published_at  \
# 0       @camatkaliguwo5666  2025-10-06T16:17:22Z
# 1              @reyy_afz34  2025-10-06T13:28:37Z
# 2                 @Karis-b  2025-10-06T11:32:17Z
# 3              @habibi3722  2025-10-06T11:03:10Z
# 4   @shadow_milk_cookie182  2025-10-06T10:34:07Z
# ..                     ...                   ...
# 95             @fanhayo_go  2025-10-03T11:33:06Z
# 96             @putrooorwr  2025-10-03T11:31:08Z
# 97            @d3n1permana  2025-10-03T11:02:20Z
# 98          @userememaja11  2025-10-03T10:53:12Z
# 99            @aryanor8036  2025-10-03T10:52:14Z
#
#                                                  text  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                   unchanged_wordcloud  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG ada racunnya gmn. Menuru...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku masak nya malam bukan siang ...
#
#                                            clean_text  \
# 0                         Kaget kalidawir tulungagung
# 1   % nyesel pilih Prabowo enak aniess pendidikan ...
# 2                          Jirr semangka setipis tisu
# 3   di. daerah Kalimantan Selatan Tabalong. ayam g...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                     B for beracun
# 97    Daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                        case_fold_text  \
# 0                         kaget kalidawir tulungagung
# 1   % nyesel pilih prabowo enak aniess pendidikan ...
# 2                          jirr semangka setipis tisu
# 3   di. daerah kalimantan selatan tabalong. ayam g...
# 4   bang kalo makanan mbg itu ada racunnya atau gm...
# ..                                                ...
# 95    mbg kalau gua pikir makanan beracun gratis jirr
# 96                                     b for beracun
# 97    daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                      punctuation_text
# 0                         kaget kalidawir tulungagung
# 1    nyesel pilih prabowo enak aniess pendidikan g...
# 2                          jirr semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   bang kalo makanan mbg itu ada racunnya atau gm...
# ..                                                ...
# 95    mbg kalau gua pikir makanan beracun gratis jirr
# 96                                     b for beracun
# 97    daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes nikmati aja kalo semua orang baik...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
# [100 rows x 7 columns]

# %%
# Define the file paths for the dictionaries
slang_file_path = '/content/drive/MyDrive/Tugas/TEKS/kamus/slang.csv'
non_standard_file_path = '/content/drive/MyDrive/Tugas/TEKS/kamus/kamuskatabaku.xlsx'

# Read the slang CSV file into a pandas DataFrame
try:
    slang_df = pd.read_csv(slang_file_path)
    print(f"Successfully read data from {slang_file_path}")
    display(slang_df.head())
except FileNotFoundError:
    print(f"Error: The file {slang_file_path} was not found.")
except Exception as e:
    print(f"An error occurred while reading the CSV file: {e}")

# Read the non-standard word Excel file into a pandas DataFrame
try:
    non_standard_df = pd.read_excel(non_standard_file_path)
    print(f"\nSuccessfully read data from {non_standard_file_path}")
    display(non_standard_df.head())
except FileNotFoundError:
    print(f"Error: The file {non_standard_file_path} was not found.")
except Exception as e:
    print(f"An error occurred while reading the Excel file: {e}")
# Out:
# Successfully read data from /content/drive/MyDrive/Tugas/TEKS/kamus/slang.csv
#      slang   formal
# 0     udah    sudah
# 1      gua      aku
# 2     ntar    nanti
# 3  be like  seperti
# 4      aja     saja
# Successfully read data from /content/drive/MyDrive/Tugas/TEKS/kamus/kamuskatabaku.xlsx
#   tidak_baku kata_baku
# 0       woww       wow
# 1      aminn      amin
# 2        met   selamat
# 3     netaas   menetas
# 4    keberpa  keberapa

# %%
# Create dictionaries for mapping slang and non-standard words
slang_dict = dict(zip(slang_df['slang'], slang_df['formal']))
non_standard_dict = dict(zip(non_standard_df['tidak_baku'], non_standard_df['kata_baku']))

# Function to replace words using the dictionaries
def replace_words(text):
    if not isinstance(text, str):
        return text
    words = text.split()
    replaced_words = [slang_dict.get(word, non_standard_dict.get(word, word)) for word in words]
    return ' '.join(replaced_words)

# Apply the replacement function to the 'punctuation_text' column
saved_comments_df['normalized_text'] = saved_comments_df['punctuation_text'].apply(replace_words)

print("Preprocessing steps applied: Case Folding, Removing Punctuation, and Standardizing words.")
display(saved_comments_df.head(100))
# Out:
# Preprocessing steps applied: Case Folding, Removing Punctuation, and Standardizing words.
#                     author          published_at  \
# 0       @camatkaliguwo5666  2025-10-06T16:17:22Z
# 1              @reyy_afz34  2025-10-06T13:28:37Z
# 2                 @Karis-b  2025-10-06T11:32:17Z
# 3              @habibi3722  2025-10-06T11:03:10Z
# 4   @shadow_milk_cookie182  2025-10-06T10:34:07Z
# ..                     ...                   ...
# 95             @fanhayo_go  2025-10-03T11:33:06Z
# 96             @putrooorwr  2025-10-03T11:31:08Z
# 97            @d3n1permana  2025-10-03T11:02:20Z
# 98          @userememaja11  2025-10-03T10:53:12Z
# 99            @aryanor8036  2025-10-03T10:52:14Z
#
#                                                  text  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                   unchanged_wordcloud  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG ada racunnya gmn. Menuru...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku masak nya malam bukan siang ...
#
#                                            clean_text  \
# 0                         Kaget kalidawir tulungagung
# 1   % nyesel pilih Prabowo enak aniess pendidikan ...
# 2                          Jirr semangka setipis tisu
# 3   di. daerah Kalimantan Selatan Tabalong. ayam g...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                     B for beracun
# 97    Daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                        case_fold_text  \
# 0                         kaget kalidawir tulungagung
# 1   % nyesel pilih prabowo enak aniess pendidikan ...
# 2                          jirr semangka setipis tisu
# 3   di. daerah kalimantan selatan tabalong. ayam g...
# 4   bang kalo makanan mbg itu ada racunnya atau gm...
# ..                                                ...
# 95    mbg kalau gua pikir makanan beracun gratis jirr
# 96                                     b for beracun
# 97    daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                      punctuation_text  \
# 0                         kaget kalidawir tulungagung
# 1    nyesel pilih prabowo enak aniess pendidikan g...
# 2                          jirr semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   bang kalo makanan mbg itu ada racunnya atau gm...
# ..                                                ...
# 95    mbg kalau gua pikir makanan beracun gratis jirr
# 96                                     b for beracun
# 97    daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes nikmati aja kalo semua orang baik...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                       normalized_text
# 0                         kaget kalidawir tulungagung
# 1   menyesal pilih prabowo enak aniess pendidikan ...
# 2                        anjing semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   kakak kalau makanan mbg itu ada racunnya atau ...
# ..                                                ...
# 95  mbg kalau aku pikir makanan beracun gratis anjing
# 96                                    b untuk beracun
# 97    daripada makan gratis mending uang ya saja bagi
# 98  sudah teman nikmati saja kalau semua orang bai...
# 99  kakak kata guru ku yang masak itu ya malam buk...
#
# [100 rows x 8 columns]

# %%
import re

# Function to remove extra whitespaces
def remove_extra_whitespace(text):
    if not isinstance(text, str):
        return text
    return re.sub(r'\s+', ' ', text).strip()

# Apply the function to the 'normalized_text' column
saved_comments_df['cleaned_ws'] = saved_comments_df['normalized_text'].apply(remove_extra_whitespace)

print("Extra whitespaces removed from 'normalized_text' and stored in 'normalized_text_cleaned_ws' column.")
display(saved_comments_df.head())
# Out:
# Extra whitespaces removed from 'normalized_text' and stored in 'normalized_text_cleaned_ws' column.
#                    author          published_at  \
# 0      @camatkaliguwo5666  2025-10-06T16:17:22Z
# 1             @reyy_afz34  2025-10-06T13:28:37Z
# 2                @Karis-b  2025-10-06T11:32:17Z
# 3             @habibi3722  2025-10-06T11:03:10Z
# 4  @shadow_milk_cookie182  2025-10-06T10:34:07Z
#
#                                                 text  \
# 0                        Kaget kalidawir tulungagung
# 1  10000000000000% nyesel pilih Prabowo enak anie...
# 2                        Jirr semangka setipis tisu😂
# 3  di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4  Bang kalo makanan MBG itu ada racunnya atau gm...
#
#                                  unchanged_wordcloud  \
# 0                        Kaget kalidawir tulungagung
# 1  10000000000000% nyesel pilih Prabowo enak anie...
# 2                        Jirr semangka setipis tisu😂
# 3  di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4  Bang kalo makanan MBG ada racunnya gmn. Menuru...
#
#                                           clean_text  \
# 0                        Kaget kalidawir tulungagung
# 1  % nyesel pilih Prabowo enak aniess pendidikan ...
# 2                         Jirr semangka setipis tisu
# 3  di. daerah Kalimantan Selatan Tabalong. ayam g...
# 4  Bang kalo makanan MBG itu ada racunnya atau gm...
#
#                                       case_fold_text  \
# 0                        kaget kalidawir tulungagung
# 1  % nyesel pilih prabowo enak aniess pendidikan ...
# 2                         jirr semangka setipis tisu
# 3  di. daerah kalimantan selatan tabalong. ayam g...
# 4  bang kalo makanan mbg itu ada racunnya atau gm...
#
#                                     punctuation_text  \
# 0                        kaget kalidawir tulungagung
# 1   nyesel pilih prabowo enak aniess pendidikan g...
# 2                         jirr semangka setipis tisu
# 3  di daerah kalimantan selatan tabalong ayam gor...
# 4  bang kalo makanan mbg itu ada racunnya atau gm...
#
#                                      normalized_text  \
# 0                        kaget kalidawir tulungagung
# 1  menyesal pilih prabowo enak aniess pendidikan ...
# 2                       anjing semangka setipis tisu
# 3  di daerah kalimantan selatan tabalong ayam gor...
# 4  kakak kalau makanan mbg itu ada racunnya atau ...
#
#                                           cleaned_ws
# 0                        kaget kalidawir tulungagung
# 1  menyesal pilih prabowo enak aniess pendidikan ...
# 2                       anjing semangka setipis tisu
# 3  di daerah kalimantan selatan tabalong ayam gor...
# 4  kakak kalau makanan mbg itu ada racunnya atau ...

# %%
# Import the StemmerFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import nltk # Import nltk for tokenization

# Download necessary NLTK data
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt')
try:
    nltk.data.find('corpora/stopwords')
except LookupError:
    nltk.download('stopwords')
try:
    nltk.data.find('tokenizers/punkt_tab')
except LookupError:
    nltk.download('punkt_tab')

# Apply tokenization and then stemming to the 'normalized_text' column
saved_comments_df['tokens'] = saved_comments_df['cleaned_ws'].apply(nltk.word_tokenize)


print("Preprocessing steps applied: Case Folding, Removing Punctuation, Standardizing words, Tokenization, and Stemming.")
display(saved_comments_df.head(100))
# Out:
# Preprocessing steps applied: Case Folding, Removing Punctuation, Standardizing words, Tokenization, and Stemming.
#                     author          published_at  \
# 0       @camatkaliguwo5666  2025-10-06T16:17:22Z
# 1              @reyy_afz34  2025-10-06T13:28:37Z
# 2                 @Karis-b  2025-10-06T11:32:17Z
# 3              @habibi3722  2025-10-06T11:03:10Z
# 4   @shadow_milk_cookie182  2025-10-06T10:34:07Z
# ..                     ...                   ...
# 95             @fanhayo_go  2025-10-03T11:33:06Z
# 96             @putrooorwr  2025-10-03T11:31:08Z
# 97            @d3n1permana  2025-10-03T11:02:20Z
# 98          @userememaja11  2025-10-03T10:53:12Z
# 99            @aryanor8036  2025-10-03T10:52:14Z
#
#                                                  text  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                   unchanged_wordcloud  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG ada racunnya gmn. Menuru...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku masak nya malam bukan siang ...
#
#                                            clean_text  \
# 0                         Kaget kalidawir tulungagung
# 1   % nyesel pilih Prabowo enak aniess pendidikan ...
# 2                          Jirr semangka setipis tisu
# 3   di. daerah Kalimantan Selatan Tabalong. ayam g...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                     B for beracun
# 97    Daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                        case_fold_text  \
# 0                         kaget kalidawir tulungagung
# 1   % nyesel pilih prabowo enak aniess pendidikan ...
# 2                          jirr semangka setipis tisu
# 3   di. daerah kalimantan selatan tabalong. ayam g...
# 4   bang kalo makanan mbg itu ada racunnya atau gm...
# ..                                                ...
# 95    mbg kalau gua pikir makanan beracun gratis jirr
# 96                                     b for beracun
# 97    daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                      punctuation_text  \
# 0                         kaget kalidawir tulungagung
# 1    nyesel pilih prabowo enak aniess pendidikan g...
# 2                          jirr semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   bang kalo makanan mbg itu ada racunnya atau gm...
# ..                                                ...
# 95    mbg kalau gua pikir makanan beracun gratis jirr
# 96                                     b for beracun
# 97    daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes nikmati aja kalo semua orang baik...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                       normalized_text  \
# 0                         kaget kalidawir tulungagung
# 1   menyesal pilih prabowo enak aniess pendidikan ...
# 2                        anjing semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   kakak kalau makanan mbg itu ada racunnya atau ...
# ..                                                ...
# 95  mbg kalau aku pikir makanan beracun gratis anjing
# 96                                    b untuk beracun
# 97    daripada makan gratis mending uang ya saja bagi
# 98  sudah teman nikmati saja kalau semua orang bai...
# 99  kakak kata guru ku yang masak itu ya malam buk...
#
#                                            cleaned_ws  \
# 0                         kaget kalidawir tulungagung
# 1   menyesal pilih prabowo enak aniess pendidikan ...
# 2                        anjing semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   kakak kalau makanan mbg itu ada racunnya atau ...
# ..                                                ...
# 95  mbg kalau aku pikir makanan beracun gratis anjing
# 96                                    b untuk beracun
# 97    daripada makan gratis mending uang ya saja bagi
# 98  sudah teman nikmati saja kalau semua orang bai...
# 99  kakak kata guru ku yang masak itu ya malam buk...
#
#                                                tokens
# 0                     [kaget, kalidawir, tulungagung]
# 1   [menyesal, pilih, prabowo, enak, aniess, pendi...
# 2                   [anjing, semangka, setipis, tisu]
# 3   [di, daerah, kalimantan, selatan, tabalong, ay...
# 4   [kakak, kalau, makanan, mbg, itu, ada, racunny...
# ..                                                ...
# 95  [mbg, kalau, aku, pikir, makanan, beracun, gra...
# 96                                [b, untuk, beracun]
# 97  [daripada, makan, gratis, mending, uang, ya, s...
# 98  [sudah, teman, nikmati, saja, kalau, semua, or...
# 99  [kakak, kata, guru, ku, yang, masak, itu, ya, ...
#
# [100 rows x 10 columns]

# %%
import nltk
from nltk.corpus import stopwords

# Download Indonesian stop words (if not already downloaded)
try:
    nltk.data.find('corpora/stopwords')
except LookupError:
    nltk.download('stopwords')

# Get the list of Indonesian stop words and add 'ya' explicitly
stop_words = set(stopwords.words('indonesian'))
stop_words.add('ya') # Explicitly add 'ya' to the stop
stop_words.add('sih') # Explicitly add 'iya' to the stop

# Function to remove stop words from a list of tokens
def remove_stopwords(tokens):
    # Ensure tokens is a list
    if not isinstance(tokens, list):
        return []
    filtered_tokens = [word for word in tokens if word not in stop_words]
    return filtered_tokens

# Apply the stop word removal function to the 'text_stemmed' column
saved_comments_df['removed_stopwords'] = saved_comments_df['tokens'].apply(remove_stopwords)

print("Preprocessing steps applied: Case Folding, Removing Punctuation, Standardizing words, Tokenization, Stemming, and Stop word removal.")
display(saved_comments_df.head(100))
# Out:
# Preprocessing steps applied: Case Folding, Removing Punctuation, Standardizing words, Tokenization, Stemming, and Stop word removal.
#                     author          published_at  \
# 0       @camatkaliguwo5666  2025-10-06T16:17:22Z
# 1              @reyy_afz34  2025-10-06T13:28:37Z
# 2                 @Karis-b  2025-10-06T11:32:17Z
# 3              @habibi3722  2025-10-06T11:03:10Z
# 4   @shadow_milk_cookie182  2025-10-06T10:34:07Z
# ..                     ...                   ...
# 95             @fanhayo_go  2025-10-03T11:33:06Z
# 96             @putrooorwr  2025-10-03T11:31:08Z
# 97            @d3n1permana  2025-10-03T11:02:20Z
# 98          @userememaja11  2025-10-03T10:53:12Z
# 99            @aryanor8036  2025-10-03T10:52:14Z
#
#                                                  text  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                   unchanged_wordcloud  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG ada racunnya gmn. Menuru...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku masak nya malam bukan siang ...
#
#                                            clean_text  \
# 0                         Kaget kalidawir tulungagung
# 1   % nyesel pilih Prabowo enak aniess pendidikan ...
# 2                          Jirr semangka setipis tisu
# 3   di. daerah Kalimantan Selatan Tabalong. ayam g...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                     B for beracun
# 97    Daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                        case_fold_text  \
# 0                         kaget kalidawir tulungagung
# 1   % nyesel pilih prabowo enak aniess pendidikan ...
# 2                          jirr semangka setipis tisu
# 3   di. daerah kalimantan selatan tabalong. ayam g...
# 4   bang kalo makanan mbg itu ada racunnya atau gm...
# ..                                                ...
# 95    mbg kalau gua pikir makanan beracun gratis jirr
# 96                                     b for beracun
# 97    daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                      punctuation_text  \
# 0                         kaget kalidawir tulungagung
# 1    nyesel pilih prabowo enak aniess pendidikan g...
# 2                          jirr semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   bang kalo makanan mbg itu ada racunnya atau gm...
# ..                                                ...
# 95    mbg kalau gua pikir makanan beracun gratis jirr
# 96                                     b for beracun
# 97    daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes nikmati aja kalo semua orang baik...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                       normalized_text  \
# 0                         kaget kalidawir tulungagung
# 1   menyesal pilih prabowo enak aniess pendidikan ...
# 2                        anjing semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   kakak kalau makanan mbg itu ada racunnya atau ...
# ..                                                ...
# 95  mbg kalau aku pikir makanan beracun gratis anjing
# 96                                    b untuk beracun
# 97    daripada makan gratis mending uang ya saja bagi
# 98  sudah teman nikmati saja kalau semua orang bai...
# 99  kakak kata guru ku yang masak itu ya malam buk...
#
#                                            cleaned_ws  \
# 0                         kaget kalidawir tulungagung
# 1   menyesal pilih prabowo enak aniess pendidikan ...
# 2                        anjing semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   kakak kalau makanan mbg itu ada racunnya atau ...
# ..                                                ...
# 95  mbg kalau aku pikir makanan beracun gratis anjing
# 96                                    b untuk beracun
# 97    daripada makan gratis mending uang ya saja bagi
# 98  sudah teman nikmati saja kalau semua orang bai...
# 99  kakak kata guru ku yang masak itu ya malam buk...
#
#                                                tokens  \
# 0                     [kaget, kalidawir, tulungagung]
# 1   [menyesal, pilih, prabowo, enak, aniess, pendi...
# 2                   [anjing, semangka, setipis, tisu]
# 3   [di, daerah, kalimantan, selatan, tabalong, ay...
# 4   [kakak, kalau, makanan, mbg, itu, ada, racunny...
# ..                                                ...
# 95  [mbg, kalau, aku, pikir, makanan, beracun, gra...
# 96                                [b, untuk, beracun]
# 97  [daripada, makan, gratis, mending, uang, ya, s...
# 98  [sudah, teman, nikmati, saja, kalau, semua, or...
# 99  [kakak, kata, guru, ku, yang, masak, itu, ya, ...
#
#                                     removed_stopwords
# 0                     [kaget, kalidawir, tulungagung]
# 1   [menyesal, pilih, prabowo, enak, aniess, pendi...
# 2                   [anjing, semangka, setipis, tisu]
# 3   [daerah, kalimantan, selatan, tabalong, ayam, ...
# 4   [kakak, makanan, mbg, racunnya, manggil, panit...
# ..                                                ...
# 95     [mbg, pikir, makanan, beracun, gratis, anjing]
# 96                                       [b, beracun]
# 97                     [makan, gratis, mending, uang]
# 98      [teman, nikmati, orang, neraka, anjing, haha]
# 99  [kakak, guru, ku, masak, malam, siang, basi, m...
#
# [100 rows x 11 columns]

# %%
# Import the StemmerFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import nltk # Import nltk for tokenization

# Create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Function to perform stemming on a list of tokens
def stem_tokens(tokens):
    # Ensure tokens is a list
    if not isinstance(tokens, list):
        return []
    stemmed_tokens = [stemmer.stem(token) for token in tokens]
    return stemmed_tokens


# Then, apply stemming to the tokens
saved_comments_df['text_stemmed'] = saved_comments_df['removed_stopwords'].apply(stem_tokens)

# %%
print("Preprocessing steps applied: Case Folding, Removing Punctuation, Standardizing words, Tokenization, Stemming, and Stop word removal.")
display(saved_comments_df.head(100))
# Out:
# Preprocessing steps applied: Case Folding, Removing Punctuation, Standardizing words, Tokenization, Stemming, and Stop word removal.
#                     author          published_at  \
# 0       @camatkaliguwo5666  2025-10-06T16:17:22Z
# 1              @reyy_afz34  2025-10-06T13:28:37Z
# 2                 @Karis-b  2025-10-06T11:32:17Z
# 3              @habibi3722  2025-10-06T11:03:10Z
# 4   @shadow_milk_cookie182  2025-10-06T10:34:07Z
# ..                     ...                   ...
# 95             @fanhayo_go  2025-10-03T11:33:06Z
# 96             @putrooorwr  2025-10-03T11:31:08Z
# 97            @d3n1permana  2025-10-03T11:02:20Z
# 98          @userememaja11  2025-10-03T10:53:12Z
# 99            @aryanor8036  2025-10-03T10:52:14Z
#
#                                                  text  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                   unchanged_wordcloud  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG ada racunnya gmn. Menuru...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku masak nya malam bukan siang ...
#
#                                            clean_text  \
# 0                         Kaget kalidawir tulungagung
# 1   % nyesel pilih Prabowo enak aniess pendidikan ...
# 2                          Jirr semangka setipis tisu
# 3   di. daerah Kalimantan Selatan Tabalong. ayam g...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                     B for beracun
# 97    Daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                        case_fold_text  \
# 0                         kaget kalidawir tulungagung
# 1   % nyesel pilih prabowo enak aniess pendidikan ...
# 2                          jirr semangka setipis tisu
# 3   di. daerah kalimantan selatan tabalong. ayam g...
# 4   bang kalo makanan mbg itu ada racunnya atau gm...
# ..                                                ...
# 95    mbg kalau gua pikir makanan beracun gratis jirr
# 96                                     b for beracun
# 97    daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                      punctuation_text  \
# 0                         kaget kalidawir tulungagung
# 1    nyesel pilih prabowo enak aniess pendidikan g...
# 2                          jirr semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   bang kalo makanan mbg itu ada racunnya atau gm...
# ..                                                ...
# 95    mbg kalau gua pikir makanan beracun gratis jirr
# 96                                     b for beracun
# 97    daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes nikmati aja kalo semua orang baik...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                       normalized_text  \
# 0                         kaget kalidawir tulungagung
# 1   menyesal pilih prabowo enak aniess pendidikan ...
# 2                        anjing semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   kakak kalau makanan mbg itu ada racunnya atau ...
# ..                                                ...
# 95  mbg kalau aku pikir makanan beracun gratis anjing
# 96                                    b untuk beracun
# 97    daripada makan gratis mending uang ya saja bagi
# 98  sudah teman nikmati saja kalau semua orang bai...
# 99  kakak kata guru ku yang masak itu ya malam buk...
#
#                                            cleaned_ws  \
# 0                         kaget kalidawir tulungagung
# 1   menyesal pilih prabowo enak aniess pendidikan ...
# 2                        anjing semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   kakak kalau makanan mbg itu ada racunnya atau ...
# ..                                                ...
# 95  mbg kalau aku pikir makanan beracun gratis anjing
# 96                                    b untuk beracun
# 97    daripada makan gratis mending uang ya saja bagi
# 98  sudah teman nikmati saja kalau semua orang bai...
# 99  kakak kata guru ku yang masak itu ya malam buk...
#
#                                                tokens  \
# 0                     [kaget, kalidawir, tulungagung]
# 1   [menyesal, pilih, prabowo, enak, aniess, pendi...
# 2                   [anjing, semangka, setipis, tisu]
# 3   [di, daerah, kalimantan, selatan, tabalong, ay...
# 4   [kakak, kalau, makanan, mbg, itu, ada, racunny...
# ..                                                ...
# 95  [mbg, kalau, aku, pikir, makanan, beracun, gra...
# 96                                [b, untuk, beracun]
# 97  [daripada, makan, gratis, mending, uang, ya, s...
# 98  [sudah, teman, nikmati, saja, kalau, semua, or...
# 99  [kakak, kata, guru, ku, yang, masak, itu, ya, ...
#
#                                     removed_stopwords  \
# 0                     [kaget, kalidawir, tulungagung]
# 1   [menyesal, pilih, prabowo, enak, aniess, pendi...
# 2                   [anjing, semangka, setipis, tisu]
# 3   [daerah, kalimantan, selatan, tabalong, ayam, ...
# 4   [kakak, makanan, mbg, racunnya, manggil, panit...
# ..                                                ...
# 95     [mbg, pikir, makanan, beracun, gratis, anjing]
# 96                                       [b, beracun]
# 97                     [makan, gratis, mending, uang]
# 98      [teman, nikmati, orang, neraka, anjing, haha]
# 99  [kakak, guru, ku, masak, malam, siang, basi, m...
#
#                                          text_stemmed
# 0                     [kaget, kalidawir, tulungagung]
# 1   [sesal, pilih, prabowo, enak, aniess, didik, g...
# 2                     [anjing, semangka, setip, tisu]
# 3   [daerah, kalimantan, selatan, tabalong, ayam, ...
# 4   [kakak, makan, mbg, racun, manggil, panitia, s...
# ..                                                ...
# 95         [mbg, pikir, makan, racun, gratis, anjing]
# 96                                         [b, racun]
# 97                     [makan, gratis, mending, uang]
# 98       [teman, nikmat, orang, neraka, anjing, haha]
# 99  [kakak, guru, ku, masak, malam, siang, basi, m...
#
# [100 rows x 12 columns]

# %%
# Manually correct specific stemming errors in the 'text_stemmed' column
def correct_stemming(tokens):
    if not isinstance(tokens, list):
        return tokens
    corrected_tokens = ['tipis' if token == 'setip' else token for token in tokens]
    return corrected_tokens

# Apply the correction function to the 'text_stemmed' column
saved_comments_df['text_stemmed'] = saved_comments_df['text_stemmed'].apply(correct_stemming)

print("Corrected 'setip' to 'tipis' in the 'text_stemmed' column.")
display(saved_comments_df.head(100))
# Out:
# Corrected 'setip' to 'tipis' in the 'text_stemmed' column.
#                     author          published_at  \
# 0       @camatkaliguwo5666  2025-10-06T16:17:22Z
# 1              @reyy_afz34  2025-10-06T13:28:37Z
# 2                 @Karis-b  2025-10-06T11:32:17Z
# 3              @habibi3722  2025-10-06T11:03:10Z
# 4   @shadow_milk_cookie182  2025-10-06T10:34:07Z
# ..                     ...                   ...
# 95             @fanhayo_go  2025-10-03T11:33:06Z
# 96             @putrooorwr  2025-10-03T11:31:08Z
# 97            @d3n1permana  2025-10-03T11:02:20Z
# 98          @userememaja11  2025-10-03T10:53:12Z
# 99            @aryanor8036  2025-10-03T10:52:14Z
#
#                                                  text  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                   unchanged_wordcloud  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG ada racunnya gmn. Menuru...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku masak nya malam bukan siang ...
#
#                                            clean_text  \
# 0                         Kaget kalidawir tulungagung
# 1   % nyesel pilih Prabowo enak aniess pendidikan ...
# 2                          Jirr semangka setipis tisu
# 3   di. daerah Kalimantan Selatan Tabalong. ayam g...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                     B for beracun
# 97    Daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                        case_fold_text  \
# 0                         kaget kalidawir tulungagung
# 1   % nyesel pilih prabowo enak aniess pendidikan ...
# 2                          jirr semangka setipis tisu
# 3   di. daerah kalimantan selatan tabalong. ayam g...
# 4   bang kalo makanan mbg itu ada racunnya atau gm...
# ..                                                ...
# 95    mbg kalau gua pikir makanan beracun gratis jirr
# 96                                     b for beracun
# 97    daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                      punctuation_text  \
# 0                         kaget kalidawir tulungagung
# 1    nyesel pilih prabowo enak aniess pendidikan g...
# 2                          jirr semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   bang kalo makanan mbg itu ada racunnya atau gm...
# ..                                                ...
# 95    mbg kalau gua pikir makanan beracun gratis jirr
# 96                                     b for beracun
# 97    daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes nikmati aja kalo semua orang baik...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                       normalized_text  \
# 0                         kaget kalidawir tulungagung
# 1   menyesal pilih prabowo enak aniess pendidikan ...
# 2                        anjing semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   kakak kalau makanan mbg itu ada racunnya atau ...
# ..                                                ...
# 95  mbg kalau aku pikir makanan beracun gratis anjing
# 96                                    b untuk beracun
# 97    daripada makan gratis mending uang ya saja bagi
# 98  sudah teman nikmati saja kalau semua orang bai...
# 99  kakak kata guru ku yang masak itu ya malam buk...
#
#                                            cleaned_ws  \
# 0                         kaget kalidawir tulungagung
# 1   menyesal pilih prabowo enak aniess pendidikan ...
# 2                        anjing semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   kakak kalau makanan mbg itu ada racunnya atau ...
# ..                                                ...
# 95  mbg kalau aku pikir makanan beracun gratis anjing
# 96                                    b untuk beracun
# 97    daripada makan gratis mending uang ya saja bagi
# 98  sudah teman nikmati saja kalau semua orang bai...
# 99  kakak kata guru ku yang masak itu ya malam buk...
#
#                                                tokens  \
# 0                     [kaget, kalidawir, tulungagung]
# 1   [menyesal, pilih, prabowo, enak, aniess, pendi...
# 2                   [anjing, semangka, setipis, tisu]
# 3   [di, daerah, kalimantan, selatan, tabalong, ay...
# 4   [kakak, kalau, makanan, mbg, itu, ada, racunny...
# ..                                                ...
# 95  [mbg, kalau, aku, pikir, makanan, beracun, gra...
# 96                                [b, untuk, beracun]
# 97  [daripada, makan, gratis, mending, uang, ya, s...
# 98  [sudah, teman, nikmati, saja, kalau, semua, or...
# 99  [kakak, kata, guru, ku, yang, masak, itu, ya, ...
#
#                                     removed_stopwords  \
# 0                     [kaget, kalidawir, tulungagung]
# 1   [menyesal, pilih, prabowo, enak, aniess, pendi...
# 2                   [anjing, semangka, setipis, tisu]
# 3   [daerah, kalimantan, selatan, tabalong, ayam, ...
# 4   [kakak, makanan, mbg, racunnya, manggil, panit...
# ..                                                ...
# 95     [mbg, pikir, makanan, beracun, gratis, anjing]
# 96                                       [b, beracun]
# 97                     [makan, gratis, mending, uang]
# 98      [teman, nikmati, orang, neraka, anjing, haha]
# 99  [kakak, guru, ku, masak, malam, siang, basi, m...
#
#                                          text_stemmed
# 0                     [kaget, kalidawir, tulungagung]
# 1   [sesal, pilih, prabowo, enak, aniess, didik, g...
# 2                     [anjing, semangka, tipis, tisu]
# 3   [daerah, kalimantan, selatan, tabalong, ayam, ...
# 4   [kakak, makan, mbg, racun, manggil, panitia, s...
# ..                                                ...
# 95         [mbg, pikir, makan, racun, gratis, anjing]
# 96                                         [b, racun]
# 97                     [makan, gratis, mending, uang]
# 98       [teman, nikmat, orang, neraka, anjing, haha]
# 99  [kakak, guru, ku, masak, malam, siang, basi, m...
#
# [100 rows x 12 columns]

# %%
print("Preprocessing steps applied: Case Folding, Removing Punctuation, Standardizing words, Tokenization, Stemming, and Stop word removal.")
display(saved_comments_df.head(100))
# Out:
# Preprocessing steps applied: Case Folding, Removing Punctuation, Standardizing words, Tokenization, Stemming, and Stop word removal.
#                     author          published_at  \
# 0       @camatkaliguwo5666  2025-10-06T16:17:22Z
# 1              @reyy_afz34  2025-10-06T13:28:37Z
# 2                 @Karis-b  2025-10-06T11:32:17Z
# 3              @habibi3722  2025-10-06T11:03:10Z
# 4   @shadow_milk_cookie182  2025-10-06T10:34:07Z
# ..                     ...                   ...
# 95             @fanhayo_go  2025-10-03T11:33:06Z
# 96             @putrooorwr  2025-10-03T11:31:08Z
# 97            @d3n1permana  2025-10-03T11:02:20Z
# 98          @userememaja11  2025-10-03T10:53:12Z
# 99            @aryanor8036  2025-10-03T10:52:14Z
#
#                                                  text  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                   unchanged_wordcloud  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG ada racunnya gmn. Menuru...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku masak nya malam bukan siang ...
#
#                                            clean_text  \
# 0                         Kaget kalidawir tulungagung
# 1   % nyesel pilih Prabowo enak aniess pendidikan ...
# 2                          Jirr semangka setipis tisu
# 3   di. daerah Kalimantan Selatan Tabalong. ayam g...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                     B for beracun
# 97    Daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                        case_fold_text  \
# 0                         kaget kalidawir tulungagung
# 1   % nyesel pilih prabowo enak aniess pendidikan ...
# 2                          jirr semangka setipis tisu
# 3   di. daerah kalimantan selatan tabalong. ayam g...
# 4   bang kalo makanan mbg itu ada racunnya atau gm...
# ..                                                ...
# 95    mbg kalau gua pikir makanan beracun gratis jirr
# 96                                     b for beracun
# 97    daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                      punctuation_text  \
# 0                         kaget kalidawir tulungagung
# 1    nyesel pilih prabowo enak aniess pendidikan g...
# 2                          jirr semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   bang kalo makanan mbg itu ada racunnya atau gm...
# ..                                                ...
# 95    mbg kalau gua pikir makanan beracun gratis jirr
# 96                                     b for beracun
# 97    daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes nikmati aja kalo semua orang baik...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                       normalized_text  \
# 0                         kaget kalidawir tulungagung
# 1   menyesal pilih prabowo enak aniess pendidikan ...
# 2                        anjing semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   kakak kalau makanan mbg itu ada racunnya atau ...
# ..                                                ...
# 95  mbg kalau aku pikir makanan beracun gratis anjing
# 96                                    b untuk beracun
# 97    daripada makan gratis mending uang ya saja bagi
# 98  sudah teman nikmati saja kalau semua orang bai...
# 99  kakak kata guru ku yang masak itu ya malam buk...
#
#                                            cleaned_ws  \
# 0                         kaget kalidawir tulungagung
# 1   menyesal pilih prabowo enak aniess pendidikan ...
# 2                        anjing semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   kakak kalau makanan mbg itu ada racunnya atau ...
# ..                                                ...
# 95  mbg kalau aku pikir makanan beracun gratis anjing
# 96                                    b untuk beracun
# 97    daripada makan gratis mending uang ya saja bagi
# 98  sudah teman nikmati saja kalau semua orang bai...
# 99  kakak kata guru ku yang masak itu ya malam buk...
#
#                                                tokens  \
# 0                     [kaget, kalidawir, tulungagung]
# 1   [menyesal, pilih, prabowo, enak, aniess, pendi...
# 2                   [anjing, semangka, setipis, tisu]
# 3   [di, daerah, kalimantan, selatan, tabalong, ay...
# 4   [kakak, kalau, makanan, mbg, itu, ada, racunny...
# ..                                                ...
# 95  [mbg, kalau, aku, pikir, makanan, beracun, gra...
# 96                                [b, untuk, beracun]
# 97  [daripada, makan, gratis, mending, uang, ya, s...
# 98  [sudah, teman, nikmati, saja, kalau, semua, or...
# 99  [kakak, kata, guru, ku, yang, masak, itu, ya, ...
#
#                                     removed_stopwords  \
# 0                     [kaget, kalidawir, tulungagung]
# 1   [menyesal, pilih, prabowo, enak, aniess, pendi...
# 2                   [anjing, semangka, setipis, tisu]
# 3   [daerah, kalimantan, selatan, tabalong, ayam, ...
# 4   [kakak, makanan, mbg, racunnya, manggil, panit...
# ..                                                ...
# 95     [mbg, pikir, makanan, beracun, gratis, anjing]
# 96                                       [b, beracun]
# 97                     [makan, gratis, mending, uang]
# 98      [teman, nikmati, orang, neraka, anjing, haha]
# 99  [kakak, guru, ku, masak, malam, siang, basi, m...
#
#                                          text_stemmed
# 0                     [kaget, kalidawir, tulungagung]
# 1   [sesal, pilih, prabowo, enak, aniess, didik, g...
# 2                     [anjing, semangka, tipis, tisu]
# 3   [daerah, kalimantan, selatan, tabalong, ayam, ...
# 4   [kakak, makan, mbg, racun, manggil, panitia, s...
# ..                                                ...
# 95         [mbg, pikir, makan, racun, gratis, anjing]
# 96                                         [b, racun]
# 97                     [makan, gratis, mending, uang]
# 98       [teman, nikmat, orang, neraka, anjing, haha]
# 99  [kakak, guru, ku, masak, malam, siang, basi, m...
#
# [100 rows x 12 columns]

# %%
# Remove the token 'ku' from the 'text_stemmed' column
def remove_specific_token(tokens, token_to_remove):
    if not isinstance(tokens, list):
        return tokens
    return [token for token in tokens if token != token_to_remove]

saved_comments_df['text_stemmed'] = saved_comments_df['text_stemmed'].apply(lambda x: remove_specific_token(x, 'ku'))
saved_comments_df['text_stemmed'] = saved_comments_df['text_stemmed'].apply(lambda x: remove_specific_token(x, 'kakak'))
saved_comments_df['text_stemmed'] = saved_comments_df['text_stemmed'].apply(lambda x: remove_specific_token(x, 'gaco'))

print("Removed 'ku' from 'text_stemmed' column.")
display(saved_comments_df.head(100))
# Out:
# Removed 'ku' from 'text_stemmed' column.
#                     author          published_at  \
# 0       @camatkaliguwo5666  2025-10-06T16:17:22Z
# 1              @reyy_afz34  2025-10-06T13:28:37Z
# 2                 @Karis-b  2025-10-06T11:32:17Z
# 3              @habibi3722  2025-10-06T11:03:10Z
# 4   @shadow_milk_cookie182  2025-10-06T10:34:07Z
# ..                     ...                   ...
# 95             @fanhayo_go  2025-10-03T11:33:06Z
# 96             @putrooorwr  2025-10-03T11:31:08Z
# 97            @d3n1permana  2025-10-03T11:02:20Z
# 98          @userememaja11  2025-10-03T10:53:12Z
# 99            @aryanor8036  2025-10-03T10:52:14Z
#
#                                                  text  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                   unchanged_wordcloud  \
# 0                         Kaget kalidawir tulungagung
# 1   10000000000000% nyesel pilih Prabowo enak anie...
# 2                         Jirr semangka setipis tisu😂
# 3   di. daerah Kalimantan Selatan Tabalong.  ayam ...
# 4   Bang kalo makanan MBG ada racunnya gmn. Menuru...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                    B for beracun 😂
# 97  Daripada makan gratis mending duit nya aja bagi2😅
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku masak nya malam bukan siang ...
#
#                                            clean_text  \
# 0                         Kaget kalidawir tulungagung
# 1   % nyesel pilih Prabowo enak aniess pendidikan ...
# 2                          Jirr semangka setipis tisu
# 3   di. daerah Kalimantan Selatan Tabalong. ayam g...
# 4   Bang kalo makanan MBG itu ada racunnya atau gm...
# ..                                                ...
# 95    MBG kalau gua pikir makanan beracun gratis jirr
# 96                                     B for beracun
# 97    Daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                        case_fold_text  \
# 0                         kaget kalidawir tulungagung
# 1   % nyesel pilih prabowo enak aniess pendidikan ...
# 2                          jirr semangka setipis tisu
# 3   di. daerah kalimantan selatan tabalong. ayam g...
# 4   bang kalo makanan mbg itu ada racunnya atau gm...
# ..                                                ...
# 95    mbg kalau gua pikir makanan beracun gratis jirr
# 96                                     b for beracun
# 97    daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes.. nikmati aja, kalo semua orang b...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                      punctuation_text  \
# 0                         kaget kalidawir tulungagung
# 1    nyesel pilih prabowo enak aniess pendidikan g...
# 2                          jirr semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   bang kalo makanan mbg itu ada racunnya atau gm...
# ..                                                ...
# 95    mbg kalau gua pikir makanan beracun gratis jirr
# 96                                     b for beracun
# 97    daripada makan gratis mending duit nya aja bagi
# 98  udahlah gaes nikmati aja kalo semua orang baik...
# 99  bang kata guru ku yang masak itu nya malam buk...
#
#                                       normalized_text  \
# 0                         kaget kalidawir tulungagung
# 1   menyesal pilih prabowo enak aniess pendidikan ...
# 2                        anjing semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   kakak kalau makanan mbg itu ada racunnya atau ...
# ..                                                ...
# 95  mbg kalau aku pikir makanan beracun gratis anjing
# 96                                    b untuk beracun
# 97    daripada makan gratis mending uang ya saja bagi
# 98  sudah teman nikmati saja kalau semua orang bai...
# 99  kakak kata guru ku yang masak itu ya malam buk...
#
#                                            cleaned_ws  \
# 0                         kaget kalidawir tulungagung
# 1   menyesal pilih prabowo enak aniess pendidikan ...
# 2                        anjing semangka setipis tisu
# 3   di daerah kalimantan selatan tabalong ayam gor...
# 4   kakak kalau makanan mbg itu ada racunnya atau ...
# ..                                                ...
# 95  mbg kalau aku pikir makanan beracun gratis anjing
# 96                                    b untuk beracun
# 97    daripada makan gratis mending uang ya saja bagi
# 98  sudah teman nikmati saja kalau semua orang bai...
# 99  kakak kata guru ku yang masak itu ya malam buk...
#
#                                                tokens  \
# 0                     [kaget, kalidawir, tulungagung]
# 1   [menyesal, pilih, prabowo, enak, aniess, pendi...
# 2                   [anjing, semangka, setipis, tisu]
# 3   [di, daerah, kalimantan, selatan, tabalong, ay...
# 4   [kakak, kalau, makanan, mbg, itu, ada, racunny...
# ..                                                ...
# 95  [mbg, kalau, aku, pikir, makanan, beracun, gra...
# 96                                [b, untuk, beracun]
# 97  [daripada, makan, gratis, mending, uang, ya, s...
# 98  [sudah, teman, nikmati, saja, kalau, semua, or...
# 99  [kakak, kata, guru, ku, yang, masak, itu, ya, ...
#
#                                     removed_stopwords  \
# 0                     [kaget, kalidawir, tulungagung]
# 1   [menyesal, pilih, prabowo, enak, aniess, pendi...
# 2                   [anjing, semangka, setipis, tisu]
# 3   [daerah, kalimantan, selatan, tabalong, ayam, ...
# 4   [kakak, makanan, mbg, racunnya, manggil, panit...
# ..                                                ...
# 95     [mbg, pikir, makanan, beracun, gratis, anjing]
# 96                                       [b, beracun]
# 97                     [makan, gratis, mending, uang]
# 98      [teman, nikmati, orang, neraka, anjing, haha]
# 99  [kakak, guru, ku, masak, malam, siang, basi, m...
#
#                                          text_stemmed
# 0                     [kaget, kalidawir, tulungagung]
# 1   [sesal, pilih, prabowo, enak, aniess, didik, g...
# 2                     [anjing, semangka, tipis, tisu]
# 3   [daerah, kalimantan, selatan, tabalong, ayam, ...
# 4   [makan, mbg, racun, manggil, panitia, suruh, c...
# ..                                                ...
# 95         [mbg, pikir, makan, racun, gratis, anjing]
# 96                                         [b, racun]
# 97                     [makan, gratis, mending, uang]
# 98       [teman, nikmat, orang, neraka, anjing, haha]
# 99  [guru, masak, malam, siang, basi, makan, gizi,...
#
# [100 rows x 12 columns]
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
# Define the file path to save the processed data
output_file_path = '/content/drive/MyDrive/Tugas/TEKS/CSV/youtube_comments_processed.csv'

# Save the processed DataFrame to a new CSV file
try:
    saved_comments_df.to_csv(output_file_path, index=False)
    print(f"Successfully saved processed data to {output_file_path}")
except Exception as e:
    print(f"An error occurred while saving the CSV file: {e}")
# Out:
# Successfully saved processed data to /content/drive/MyDrive/Tugas/TEKS/CSV/youtube_comments_processed.csv

# %% [markdown]
# **Reasoning**:
# Create dictionaries from the loaded dataframes and define functions to replace slang and non-standard words.

# %% [markdown]
# # EDA

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.12/dist-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from wordcloud) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from wordcloud) (11.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
from collections import Counter

# Combine all the cleaned tokens into a single list, filtering out empty strings
all_cleaned_tokens = [token for tokens_list in saved_comments_df['text_stemmed'] for token in tokens_list if token.strip() != '']


# Count the frequency of each token
word_counts_clean = Counter(all_cleaned_tokens)

# Get the most common words (e.g., top 100)
most_common_words_clean = word_counts_clean.most_common(100)

print("Most common words after preprocessing:")
for word, count in most_common_words_clean:
    print(f"{word}: {count}")
# Out:
# Most common words after preprocessing:
# makan: 684
# mbg: 679
# racun: 389
# gratis: 321
# sekolah: 282
# korupsi: 247
# gizi: 226
# program: 171
# orang: 142
# hiu: 136
# semangka: 135
# enak: 116
# indonesia: 111
# anak: 109
# ikan: 109
# anjing: 108
# salah: 108
# kasih: 105
# uang: 99
# bagus: 86
# perintah: 82
# mie: 81
# untung: 79
# rakyat: 77
# dapur: 76
# masak: 76
# aman: 73
# bikin: 72
# menu: 69
# tipis: 67
# goreng: 65
# prabowo: 63
# daerah: 62
# tau: 62
# teman: 60
# basi: 59
# dana: 53
# pas: 52
# siswa: 51
# jir: 51
# vendor: 51
# masuk: 50
# nasi: 46
# ayam: 45
# sayur: 44
# bilang: 43
# jabat: 42
# negara: 41
# biar: 40
# mah: 40
# alhamdulilah: 39
# kalidawir: 38
# anggar: 38
# oknum: 38
# bang: 36
# sehat: 36
# pakai: 35
# tanggung: 34
# kerja: 34
# ribu: 34
# presiden: 33
# bahan: 33
# lihat: 33
# burger: 32
# sakit: 31
# mending: 31
# daging: 31
# langsung: 30
# nama: 30
# coba: 30
# rumah: 29
# ahli: 28
# porsi: 28
# belatung: 28
# katsu: 28
# tua: 27
# iya: 27
# kota: 27
# bau: 26
# beda: 26
# suka: 26
# habis: 25
# kualitas: 25
# main: 25
# beli: 25
# jujur: 25
# laksana: 24
# sppg: 24
# tinggal: 24
# hasil: 24
# cerita: 24
# bodoh: 23
# jam: 23
# ganti: 23
# aneh: 23
# siang: 22
# omong: 22
# doang: 22
# tulungagung: 21
# hukum: 21

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure most_common_words_clean is available from the previous cell
if 'most_common_words_clean' in locals():
    # Prepare data for visualization, take only the top 20
    words_clean, counts_clean = zip(*most_common_words_clean[:20])

    # Create a bar plot
    plt.figure(figsize=(12, 8))
    sns.barplot(x=list(counts_clean), y=list(words_clean), palette='viridis')
    plt.title('Top 20 Most Frequent Words (Cleaned Text)')
    plt.xlabel('Frequency')
    plt.ylabel('Words')
    plt.show()
else:
    print("Error: 'most_common_words_clean' not found. Please run the previous cell to identify the most common words first.")
# Out:
# /tmp/ipython-input-859491720.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(counts_clean), y=list(words_clean), palette='viridis')

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Ensure most_common_words_clean is available
if 'most_common_words_clean' in locals():
    # Create a dictionary from the most common words and their counts
    word_freq_dict = dict(most_common_words_clean)

    # Create and generate a wordcloud image from the frequency dictionary
    wordcloud_freq = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate_from_frequencies(word_freq_dict)

    print("Word cloud from frequent words object created.")

    # Display the generated word cloud image
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_freq, interpolation='bilinear')
    plt.axis('off')
    plt.title('Word Cloud of Most Frequent Words (Cleaned Text)')
    plt.show()
else:
    print("Error: 'most_common_words_clean' not found. Please run the previous cell to identify the most common words first.")
# Out:
# Word cloud from frequent words object created.

# %%
from collections import Counter
import nltk

# Ensure nltk punkt tokenizer is available
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt')


# Function to generate n-grams from a list of tokens, filtering empty tokens
def generate_ngrams_filtered(tokens, n):
    if not isinstance(tokens, list):
        return []
    # Filter out empty strings before generating ngrams
    filtered_tokens = [token for token in tokens if token.strip() != '']
    if len(filtered_tokens) < n:
        return []
    return list(nltk.ngrams(filtered_tokens, n))

# Generate and count bigrams from the 'text_stemmed' column using the filtered function
all_bigrams = [ngram for tokens_list in saved_comments_df['text_stemmed']
               for ngram in generate_ngrams_filtered(tokens_list, 2)]

bigram_counts = Counter(all_bigrams)
most_common_bigrams = bigram_counts.most_common(100)

print("Most common Bigrams:")
for bigram, count in most_common_bigrams:
    print(f"{bigram}: {count}")

print("\n" + "="*30 + "\n") # Separator

# Generate and count trigrams from the 'text_stemmed' column using the filtered function
all_trigrams = [ngram for tokens_list in saved_comments_df['text_stemmed']
                for ngram in generate_ngrams_filtered(tokens_list, 3)]

trigram_counts = Counter(all_trigrams)
most_common_trigrams = trigram_counts.most_common(100)

print("Most common Trigrams:")
for trigram, count in most_common_trigrams:
    print(f"{trigram}: {count}")
# Out:
# Most common Bigrams:
# ('makan', 'racun'): 124
# ('racun', 'gratis'): 121
# ('makan', 'gizi'): 94
# ('mbg', 'makan'): 91
# ('ikan', 'hiu'): 80
# ('gizi', 'gratis'): 72
# ('hiu', 'goreng'): 44
# ('makan', 'mbg'): 43
# ('semangka', 'tipis'): 38
# ('sekolah', 'mbg'): 36
# ('gratis', 'makan'): 33
# ('makan', 'gratis'): 31
# ('program', 'mbg'): 31
# ('dapur', 'mbg'): 30
# ('orang', 'tua'): 24
# ('mie', 'gizi'): 24
# ('mbg', 'racun'): 23
# ('program', 'bagus'): 22
# ('ahli', 'gizi'): 21
# ('makan', 'basi'): 19
# ('untung', 'sekolah'): 18
# ('gratis', 'mbg'): 17
# ('chum', 'bucket'): 16
# ('racun', 'makan'): 16
# ('mbg', 'sekolah'): 15
# ('hiu', 'enak'): 14
# ('mbg', 'enak'): 14
# ('alhamdulilah', 'sekolah'): 14
# ('makan', 'makan'): 14
# ('indonesia', 'emas'): 14
# ('makan', 'ikan'): 13
# ('makan', 'enak'): 13
# ('makan', 'siang'): 13
# ('untung', 'mbg'): 13
# ('aman', 'aman'): 13
# ('chicken', 'katsu'): 13
# ('adek', 'inoen'): 13
# ('a', 'href'): 13
# ('tipis', 'tisu'): 12
# ('masuk', 'kantong'): 12
# ('anak', 'sekolah'): 12
# ('racun', 'mbg'): 11
# ('indonesia', 'cemas'): 11
# ('enak', 'enak'): 11
# ('sekolah', 'aman'): 11
# ('mbg', 'korupsi'): 11
# ('siswa', 'racun'): 11
# ('kasih', 'makan'): 10
# ('siang', 'gratis'): 10
# ('anak', 'anak'): 10
# ('anak', 'orang'): 9
# ('basi', 'makan'): 9
# ('basi', 'gratis'): 9
# ('menu', 'mbg'): 9
# ('makan', 'hiu'): 9
# ('anak', 'racun'): 9
# ('emas', 'indonesia'): 9
# ('anggar', 'mbg'): 9
# ('semangka', 'kertas'): 8
# ('b', 'racun'): 8
# ('mbg', 'menu'): 8
# ('gara', 'gara'): 8
# ('rumah', 'sakit'): 8
# ('rakyat', 'korupsi'): 8
# ('mbgmakan', 'racun'): 8
# ('mbg', 'daerah'): 8
# ('oke', 'gas'): 8
# ('dana', 'mbg'): 8
# ('oknum', 'korupsi'): 8
# ('program', 'makan'): 8
# ('didik', 'gratis'): 7
# ('orang', 'racun'): 7
# ('salah', 'program'): 7
# ('belatung', 'gratis'): 7
# ('gizi', 'racun'): 7
# ('uang', 'korupsi'): 7
# ('perintah', 'rakyat'): 7
# ('sekolah', 'makan'): 7
# ('salah', 'perintah'): 7
# ('mie', 'makan'): 7
# ('mbg', 'anjing'): 7
# ('sekolah', 'racun'): 7
# ('ladang', 'korupsi'): 7
# ('sayur', 'basi'): 7
# ('kasih', 'tau'): 7
# ('potong', 'semangka'): 7
# ('hadiah', 'bikin'): 7
# ('hiu', 'makan'): 7
# ('tipis', 'kertas'): 7
# ('gizi', 'makan'): 7
# ('daging', 'hiu'): 7
# ('kalidawir', 'tulungagung'): 6
# ('bahan', 'makan'): 6
# ('makan', 'belatung'): 6
# ('tua', 'siswa'): 6
# ('terima', 'kasih'): 6
# ('mbg', 'bagus'): 6
# ('jam', 'siang'): 6
# ('singkat', 'makan'): 6
# ('sekolah', 'sekolah'): 6
#
# ==============================
#
# Most common Trigrams:
# ('makan', 'racun', 'gratis'): 98
# ('makan', 'gizi', 'gratis'): 62
# ('mbg', 'makan', 'racun'): 38
# ('gizi', 'gratis', 'makan'): 27
# ('ikan', 'hiu', 'goreng'): 23
# ('mbg', 'makan', 'gizi'): 22
# ('gratis', 'makan', 'racun'): 17
# ('gratis', 'mbg', 'makan'): 13
# ('makan', 'siang', 'gratis'): 10
# ('gizi', 'gratis', 'mbg'): 10
# ('makan', 'ikan', 'hiu'): 9
# ('ikan', 'hiu', 'enak'): 9
# ('indonesia', 'emas', 'indonesia'): 9
# ('untung', 'sekolah', 'mbg'): 8
# ('makan', 'basi', 'gratis'): 8
# ('mbgmakan', 'racun', 'gratis'): 8
# ('semangka', 'tipis', 'tisu'): 7
# ('orang', 'tua', 'siswa'): 6
# ('bucket', 'dapur', 'mbg'): 6
# ('semangka', 'tipis', 'kertas'): 6
# ('anak', 'orang', 'racun'): 5
# ('masuk', 'rumah', 'sakit'): 5
# ('gratis', 'makan', 'gratis'): 5
# ('chum', 'bucket', 'dapur'): 5
# ('gizi', 'gratis', 'mbgmakan'): 5
# ('mie', 'makan', 'gizi'): 5
# ('mbg', 'chum', 'bucket'): 5
# ('bayar', 'pakai', 'pajak'): 4
# ('makan', 'belatung', 'gratis'): 4
# ('kasih', 'orang', 'tua'): 4
# ('gratis', 'makan', 'basi'): 4
# ('episode', 'buruk', 'israel'): 4
# ('alhamdulilah', 'sekolah', 'aman'): 4
# ('mbg', 'singkat', 'makan'): 4
# ('mbgmakan', 'gizi', 'gratis'): 4
# ('kasih', 'uang', 'orang'): 4
# ('uang', 'orang', 'tua'): 4
# ('oke', 'gas', 'oke'): 4
# ('gas', 'oke', 'gas'): 4
# ('makan', 'basi', 'makan'): 4
# ('emas', 'indonesia', 'cemas'): 4
# ('gratis', 'mbgmakan', 'racun'): 4
# ('korupsi', 'anggar', 'mbg'): 4
# ('cerita', 'inspiratif', 'visual'): 4
# ('inspiratif', 'visual', 'keren'): 4
# ('cerita', 'hubung', 'hadiah'): 4
# ('hadiah', 'bikin', 'semangat'): 4
# ('menu', 'ikan', 'hiu'): 4
# ('ikan', 'hiu', 'makan'): 4
# ('racun', 'gratis', 'indonesia'): 4
# ('gratis', 'indonesia', 'emas'): 4
# ('daging', 'ikan', 'hiu'): 4
# ('dapur', 'mbg', 'chum'): 4
# ('program', 'bagus', 'eksekusi'): 4
# ('makan', 'mbg', 'racun'): 3
# ('gratis', 'bayar', 'pakai'): 3
# ('mbg', 'mmakan', 'bberacun'): 3
# ('serba', 'serbi', 'makan'): 3
# ('serbi', 'makan', 'racun'): 3
# ('masuk', 'kantong', 'pribadi'): 3
# ('racun', 'gratis', 'anjing'): 3
# ('mrg', 'makan', 'racun'): 3
# ('makan', 'gizi', 'mie'): 3
# ('semangka', 'tipis', 'harap'): 3
# ('racun', 'makan', 'mbg'): 3
# ('mbg', 'b', 'racun'): 3
# ('hukum', 'mati', 'koruptor'): 3
# ('mbgmakanan', 'racun', 'gratis'): 3
# ('ikan', 'hiu', 'saus'): 3
# ('hiu', 'saus', 'tomat'): 3
# ('sekolah', 'aman', 'aman'): 3
# ('b', 'racun', 'gratis'): 3
# ('korupsi', 'darah', 'daging'): 3
# ('racun', 'makan', 'basi'): 3
# ('nama', 'mbg', 'makan'): 3
# ('mbg', 'makan', 'basi'): 3
# ('makan', 'racun', 'gerat'): 3
# ('cerita', 'penuh', 'makna'): 3
# ('a', 'href', 'subhanallah'): 3
# ('href', 'subhanallah', 'bikin'): 3
# ('subhanallah', 'bikin', 'alam'): 3
# ('bikin', 'alam', 'main'): 3
# ('alam', 'main', 'beda'): 3
# ('main', 'beda', 'cerita'): 3
# ('beda', 'cerita', 'inspiratif'): 3
# ('bikin', 'seru', 'cerita'): 3
# ('seru', 'cerita', 'hubung'): 3
# ('hubung', 'hadiah', 'bikin'): 3
# ('bikin', 'mikir', 'visual'): 3
# ('potong', 'semangka', 'tipis'): 3
# ('ikan', 'hiu', 'ikan'): 3
# ('hiu', 'enak', 'loh'): 3
# ('gizi', 'ahli', 'gizi'): 3
# ('anjing', 'semangka', 'tipis'): 2
# ('sekian', 'terima', 'gaji'): 2
# ('bodoh', 'anak', 'orang'): 2
# ('program', 'racun', 'massal'): 2
# ('kasih', 'makan', 'gratis'): 2
# ('salah', 'program', 'salah'): 2
# ('mmakan', 'bberacun', 'ggeratis'): 2

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure most_common_bigrams is available from the previous cell
if 'most_common_bigrams' in locals():
    # Prepare data for visualization
    bigram_phrases = [' '.join(bigram[0]) for bigram in most_common_bigrams[:50]]
    bigram_counts_values = [bigram[1] for bigram in most_common_bigrams[:50]]

    # Create a bar plot for bigrams
    plt.figure(figsize=(12, 8))
    sns.barplot(x=bigram_counts_values, y=bigram_phrases, palette='viridis')
    plt.title('Top 20 Most Frequent Bigrams')
    plt.xlabel('Frequency')
    plt.ylabel('Bigrams')
    plt.show()
else:
    print("Error: 'most_common_bigrams' not found. Please run the previous cell to generate bigrams first.")
# Out:
# /tmp/ipython-input-2150484331.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=bigram_counts_values, y=bigram_phrases, palette='viridis')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure most_common_trigrams is available from the previous cell
if 'most_common_trigrams' in locals():
    # Prepare data for visualization
    trigram_phrases = [' '.join(trigram[0]) for trigram in most_common_trigrams[:50]]
    trigram_counts_values = [trigram[1] for trigram in most_common_trigrams[:50]]

    # Create a bar plot for trigrams
    plt.figure(figsize=(12, 8))
    sns.barplot(x=trigram_counts_values, y=trigram_phrases, palette='viridis')
    plt.title('Top 20 Most Frequent Trigrams')
    plt.xlabel('Frequency')
    plt.ylabel('Trigrams')
    plt.show()
else:
    print("Error: 'most_common_trigrams' not found. Please run the previous cell to generate trigrams first.")
# Out:
# /tmp/ipython-input-2739821995.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=trigram_counts_values, y=trigram_phrases, palette='viridis')

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Ensure most_common_bigrams is available
if 'most_common_bigrams' in locals():
    # Combine the most common bigrams into a single list of strings
    # Represent each bigram as a single string
    bigram_strings = [' '.join(bigram[0]) for bigram in most_common_bigrams]

    # Combine all the bigram strings into a single string for the word cloud
    bigram_wordcloud_text = ' '.join(bigram_strings)

    # Create and generate a wordcloud image
    # Consider increasing max_words if you want to include more bigrams than the top 20
    wordcloud_bigram = WordCloud(width=800, height=400, background_color='white', colormap='viridis', max_words=100).generate(bigram_wordcloud_text)

    print("Bigram word cloud object created.")

    # Display the generated word cloud image
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_bigram, interpolation='bilinear')
    plt.axis('off')
    plt.title('Word Cloud of Most Frequent Bigrams')
    plt.show()
else:
    print("Error: 'most_common_bigrams' not found. Please run the previous cell to generate bigrams first.")
# Out:
# Bigram word cloud object created.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Ensure most_common_trigrams is available
if 'most_common_trigrams' in locals():
    # Combine the most common trigrams into a single list of strings
    # Represent each trigram as a single string
    trigram_strings = [' '.join(trigram[0]) for trigram in most_common_trigrams]

    # Combine all the trigram strings into a single string for the word cloud
    trigram_wordcloud_text = ' '.join(trigram_strings)

    # Create and generate a wordcloud image
    # Consider increasing max_words if you want to include more trigrams than the top 20
    wordcloud_trigram = WordCloud(width=800, height=400, background_color='white', colormap='viridis', max_words=100).generate(trigram_wordcloud_text)

    print("Trigram word cloud object created.")

    # Display the generated word cloud image
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud_trigram, interpolation='bilinear')
    plt.axis('off')
    plt.title('Word Cloud of Most Frequent Trigrams')
    plt.show()
else:
    print("Error: 'most_common_trigrams' not found. Please run the previous cell to generate trigrams first.")
# Out:
# Trigram word cloud object created.
